# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Get Continent name
import pycountry_convert as pc
import pycountry

from datetime import datetime

#Disable Warning in cell 6
pd.options.mode.chained_assignment = None
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-111-f0ed91faeb42> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5
#       6 #Get Continent name
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv('ecdc-covid-data.csv')
df.tail(5)
# Out:
#       iso_code  location        date  total_cases  new_cases  total_deaths  \
# 12241      ZWE  Zimbabwe  2020-04-17           24          1             3
# 12242      ZWE  Zimbabwe  2020-04-18           24          0             3
# 12243      ZWE  Zimbabwe  2020-04-19           25          1             3
# 12244      ZWE  Zimbabwe  2020-04-20           25          0             3
# 12245      ZWE  Zimbabwe  2020-04-21           25          0             3
#
#        new_deaths  total_cases_per_million  new_cases_per_million  \
# 12241           0                    1.615                  0.067
# 12242           0                    1.615                  0.000
# 12243           0                    1.682                  0.067
# 12244           0                    1.682                  0.000
# 12245           0                    1.682                  0.000
#
#        total_deaths_per_million  new_deaths_per_million  total_tests  \
# 12241                     0.202                     0.0          NaN
# 12242                     0.202                     0.0          NaN
# 12243                     0.202                     0.0          NaN
# 12244                     0.202                     0.0          NaN
# 12245                     0.202                     0.0          NaN
#
#        new_tests  total_tests_per_thousand  new_tests_per_thousand tests_units
# 12241        NaN                       NaN                     NaN         NaN
# 12242        NaN                       NaN                     NaN         NaN
# 12243        NaN                       NaN                     NaN         NaN
# 12244        NaN                       NaN                     NaN         NaN
# 12245        NaN                       NaN                     NaN         NaN

# %%
# Change 'Bonaire Sint Eustatius and Saba'
df[df.location == 'Bonaire Sint Eustatius and Saba'].head()
# Out:
#      iso_code                         location        date  total_cases  \
# 1065      BES  Bonaire Sint Eustatius and Saba  2020-04-02            2
# 1066      BES  Bonaire Sint Eustatius and Saba  2020-04-03            2
# 1067      BES  Bonaire Sint Eustatius and Saba  2020-04-04            2
# 1068      BES  Bonaire Sint Eustatius and Saba  2020-04-05            2
# 1069      BES  Bonaire Sint Eustatius and Saba  2020-04-06            2
#
#       new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 1065          2             0           0                   76.275
# 1066          0             0           0                   76.275
# 1067          0             0           0                   76.275
# 1068          0             0           0                   76.275
# 1069          0             0           0                   76.275
#
#       new_cases_per_million  total_deaths_per_million  new_deaths_per_million  \
# 1065                 76.275                       0.0                     0.0
# 1066                  0.000                       0.0                     0.0
# 1067                  0.000                       0.0                     0.0
# 1068                  0.000                       0.0                     0.0
# 1069                  0.000                       0.0                     0.0
#
#       total_tests  new_tests  total_tests_per_thousand  \
# 1065          NaN        NaN                       NaN
# 1066          NaN        NaN                       NaN
# 1067          NaN        NaN                       NaN
# 1068          NaN        NaN                       NaN
# 1069          NaN        NaN                       NaN
#
#       new_tests_per_thousand tests_units
# 1065                     NaN         NaN
# 1066                     NaN         NaN
# 1067                     NaN         NaN
# 1068                     NaN         NaN
# 1069                     NaN         NaN

# %%
#Add continent column - this results in errors because country name differentiate
to_country_code = lambda row: pc.country_name_to_country_alpha2(row, cn_name_format="default")
try:
    country_code = df['location'].apply(to_country_code)
except:
    NameError

# %%
#The stuck countries are below
stuck_countries = set()
for row in df['location']:
    try:
        pc.country_name_to_country_alpha2(row, cn_name_format="default")
    except:
        stuck_countries.add(row)
print ('stuck_countries: {}'.format(stuck_countries))

stuck_alpha2 = set()
for row in df['location']:
    try:
        continents[pc.country_alpha2_to_continent_code(pc.country_name_to_country_alpha2(row))]
    except:
        stuck_alpha2.add(row)
print ('stuck_alpha2: {}'.format(stuck_alpha2))
# Out:
# stuck_countries: {'Curacao', 'Kosovo', "Cote d'Ivoire", 'Bonaire Sint Eustatius and Saba', 'Vatican', 'Timor', 'Democratic Republic of Congo', 'Faeroe Islands'}
# stuck_alpha2: {'Ecuador', 'Pakistan', 'South Sudan', 'Azerbaijan', 'Bangladesh', 'Bermuda', 'South Korea', 'Mexico', 'Saudi Arabia', 'Belgium', 'Dominica', 'Kuwait', 'Mali', 'Estonia', 'Northern Mariana Islands', 'Georgia', 'Kenya', 'Switzerland', 'Germany', 'Curacao', 'Algeria', 'Guyana', 'Israel', 'South Africa', 'Bonaire Sint Eustatius and Saba', 'Serbia', 'Zambia', 'Angola', 'Greenland', 'Guinea', 'Guernsey', 'Benin', 'Nepal', 'Aruba', 'Ireland', 'Papua New Guinea', 'Taiwan', 'Libya', 'Togo', 'Uruguay', 'Peru', 'United States', 'Sao Tome and Principe', 'Malaysia', 'Belarus', 'Finland', 'Central African Republic', 'Costa Rica', 'Haiti', 'Bosnia and Herzegovina', 'Guatemala', 'French Polynesia', 'Spain', 'Netherlands', 'Turkey', 'Vatican', 'Italy', 'Djibouti', 'Venezuela', 'Seychelles', 'Guinea-Bissau', 'Brunei', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Malawi', 'Somalia', 'Palestine', 'Fiji', 'Slovakia', 'Cambodia', 'Senegal', 'Bulgaria', 'Equatorial Guinea', 'Sri Lanka', 'Montserrat', 'Hungary', 'Ethiopia', 'Uganda', 'Portugal', 'Australia', 'Gambia', 'Chile', 'Laos', 'Tunisia', 'Gabon', 'Saint Kitts and Nevis', 'San Marino', 'New Caledonia', 'Romania', 'Mongolia', 'Falkland Islands', 'Niger', 'Brazil', 'Madagascar', 'Swaziland', 'Eritrea', 'Honduras', 'Indonesia', 'Democratic Republic of Congo', 'New Zealand', 'Suriname', 'Cayman Islands', 'Chad', 'Jordan', 'Hong Kong', 'Zimbabwe', 'Argentina', 'Luxembourg', 'Morocco', 'Russia', 'United Kingdom', 'Trinidad and Tobago', 'Sint Maarten (Dutch part)', 'Monaco', 'United States Virgin Islands', 'Denmark', 'Thailand', 'Jersey', 'Dominican Republic', 'Moldova', 'Panama', 'Afghanistan', 'Botswana', 'Poland', 'Macedonia', 'Rwanda', 'Gibraltar', 'Latvia', 'Cameroon', 'Kosovo', 'Malta', 'Nicaragua', "Cote d'Ivoire", 'Oman', 'Cyprus', 'Kyrgyzstan', 'Myanmar', 'Belize', 'Barbados', 'Iceland', 'Antigua and Barbuda', 'India', 'Ukraine', 'Croatia', 'Montenegro', 'Faeroe Islands', 'Isle of Man', 'Uzbekistan', 'Canada', 'Burundi', 'Congo', 'Maldives', 'Sudan', 'France', 'Anguilla', 'Syria', 'China', 'Albania', 'Bhutan', 'Bahamas', 'British Virgin Islands', 'Paraguay', 'Philippines', 'Turks and Caicos Islands', 'Lithuania', 'Mozambique', 'Bolivia', 'Greece', 'Namibia', 'Cuba', 'Iran', 'United Arab Emirates', 'Egypt', 'El Salvador', 'Singapore', 'Grenada', 'Japan', 'Mauritania', 'Nigeria', 'Guam', 'Ghana', 'Vietnam', 'Sierra Leone', 'Norway', 'Timor', 'Colombia', 'Sweden', 'Austria', 'Liechtenstein', 'Liberia', 'Iraq', 'Armenia', 'Czech Republic', 'Bahrain', 'Kazakhstan', 'Qatar', 'Lebanon', 'Andorra', 'Burkina Faso', 'Yemen', 'Mauritius', 'Puerto Rico', 'Slovenia', 'Tanzania', 'Jamaica', 'Cape Verde'}

# %%
#Rename some countries to work

#Côte d'Ivoire
location_ivory_coast = df.location[df.location == "Cote d'Ivoire"]
df.location[df.location == "Cote d'Ivoire"] = location_ivory_coast.replace(to_replace = "Cote d'Ivoire",value="Côte d'Ivoire")

#Faroe Islands
location_faroe_islands = df.location[df.location == "Faeroe Islands"]
df.location[df.location == "Faeroe Islands"] = location_faroe_islands.replace(to_replace = "Faeroe Islands",value="Faroe Islands")

#Democratic Republic of the Congo
location_drc = df.location[df.location == "Democratic Republic of Congo"]
df.location[df.location == "Democratic Republic of Congo"] = location_drc.replace(to_replace = "Democratic Republic of Congo",value="Democratic Republic of the Congo")

#Curaçao
location_curacao = df.location[df.location == "Curacao"]
df.location[df.location == "Curacao"] = location_curacao.replace(to_replace = "Curacao",value="Curaçao")


#Reset Timor to Timor-Leste (proper name)
location_timor = df.location[df.location == "Timor"]
df.location[df.location == "Timor"] = location_timor.replace(to_replace = "Timor",value="Timor-Leste")

# %%
def create_continent():
    
    '''
    Input: None
    Output: Complete series with continent names
    '''
    #Initializes new Series
    conti_column = pd.Series([],dtype='object')

    continents = {
        'NA': 'North America',
        'SA': 'South America', 
        'AS': 'Asia',
        'OC': 'Australia',
        'AF': 'Africa',
        'EU': 'Europe'}
    
    #Checks which countries have problems using when converting from the 2 country
    #code to continent name, adds these countries to a set
    stuck_alpha2 = set()
    for row in df['location']:
        try:
            continents[pc.country_alpha2_to_continent_code(pc.country_name_to_country_alpha2(row))]
        except:
            stuck_alpha2.add(row)
    
    #Fills in continent name for countries without converting problems and leaves the
    #others as np.nan
    for index,country in enumerate(df.location):
        if country in set(df.location[~df['location'].isin(list(stuck_alpha2))]):
            conti_column.loc[index] = continents[pc.country_alpha2_to_continent_code(pc.country_name_to_country_alpha2(country))]
        else:
            conti_column.loc[index] = np.nan

    #Manually add Continent names for the stuck_alpha2 countries
    conti_column[df.location == "Bonaire Sint Eustatius and Saba"] = "NA"
    conti_column[df.location == "Vatican"] = "EU"
    conti_column[df.location == "Sint Maarten (Dutch part)"] = "NA"
    conti_column[df.location == "Timor-Leste"] = "AS"
    conti_column[df.location == "Kosovo"] = "EU"
    
    return conti_column

df['continent'] = create_continent()

# %%
df.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  new_deaths_per_million  total_tests  new_tests  \
# 0                       0.0                     0.0          NaN        NaN
# 1                       0.0                     0.0          NaN        NaN
# 2                       0.0                     0.0          NaN        NaN
# 3                       0.0                     0.0          NaN        NaN
# 4                       0.0                     0.0          NaN        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand tests_units      continent
# 0                       NaN                     NaN         NaN  North America
# 1                       NaN                     NaN         NaN  North America
# 2                       NaN                     NaN         NaN  North America
# 3                       NaN                     NaN         NaN  North America
# 4                       NaN                     NaN         NaN  North America

# %%
#Check for nan Values
df.isna().sum().continent
# Out:
# 0

# %% [markdown]
# ## Explore Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12246 entries, 0 to 12245
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   iso_code                  12246 non-null  object
#  1   location                  12246 non-null  object
#  2   date                      12246 non-null  object
#  3   total_cases               12246 non-null  int64
#  4   new_cases                 12246 non-null  int64
#  5   total_deaths              12246 non-null  int64
#  6   new_deaths                12246 non-null  int64
#  7   total_cases_per_million   12056 non-null  float64
#  8   new_cases_per_million     12056 non-null  float64
#  9   total_deaths_per_million  12056 non-null  float64
#  10  new_deaths_per_million    12056 non-null  float64
#  11  total_tests               2668 non-null   float64
#  12  new_tests                 2362 non-null   float64
#  13  total_tests_per_thousand  2668 non-null   float64
#  14  new_tests_per_thousand    2365 non-null   float64
#  15  tests_units               2668 non-null   object
#  16  continent                 12246 non-null  object
# dtypes: float64(8), int64(4), object(5)
# memory usage: 1.6+ MB

# %%
#Make date variable of datetime attribute
df['date'] = pd.to_datetime(df.date,format = '%Y/%m/%d')

# %%
df.tests_units[df.tests_units.notna()].value_counts()
# Out:
# tests performed                                811
# units unclear                                  662
# people tested                                  535
# cases tested                                   269
# samples tested                                 202
# samples processed                               47
# inconsistent units (COVID Tracking Project)     45
# tests sampled                                   40
# samples analyzed                                31
# analysed samples                                26
# Name: tests_units, dtype: int64

# %%
#Global cases

fig = plt.figure()
ax = plt.axes()

#ax.plot(x, np.sin(x));
#data
groupby_global = df.groupby('date').sum()
x = groupby_global.index
y = groupby_global.total_cases

#plot
ax.plot(x,y,c='r')
ax.bar(x,y)
ax.tick_params(axis='x',which='both',labelbottom=False)
ax.set_title('Global cases over time')
ax.set_xlabel("Date")
ax.set_ylabel("Cases")

#save figure
plt.savefig('/Users/sebastiangraff/Desktop/Data_Analysis/COVID19-Exploration/plot_images/global_cases.png')
plt.show();

# %%
#Global cases vs deaths
fig, ax = plt.subplots(figsize = (15,5),nrows=1,ncols=2)

#data
groupby_global = df.groupby('date').sum()
x = groupby_global.index
y1 = groupby_global.total_cases
y2 = groupby_global.total_deaths

#plot
ax[0].plot(x,y1,c='purple',label='Cases')
ax[0].plot(x,y2,c='red',label='Deaths')
ax[0].tick_params(axis='x',which='both',labelbottom=False)
ax[0].set_title('Global cases over time')
ax[0].set_xlabel("Date")
ax[0].set_ylabel("Cases")

ax[1].plot(x,y1,c='purple',label='Cases')
ax[1].plot(x,y2,c='red',label='Deaths')
ax[1].tick_params(axis='x',which='both',labelbottom=False)
ax[1].set_title('Global logarithimic cases over time,')
ax[1].set_xlabel("Date")
ax[1].set_ylabel("Cases")
ax[1].set_yscale('log')

#save figure
ax[0].legend()
ax[1].legend()
plt.savefig('/Users/sebastiangraff/Desktop/Data_Analysis/COVID19-Exploration/plot_images/global_cases_vs_deaths.png')
plt.show();

# %%
groupby_global = df.groupby('date').sum()
groupby_global
# Out:
#             total_cases  new_cases  total_deaths  new_deaths  \
# date
# 2019-12-31           27         27             0           0
# 2020-01-01           27          0             0           0
# 2020-01-02           27          0             0           0
# 2020-01-03           44         17             0           0
# 2020-01-04           44          0             0           0
# ...                 ...        ...           ...         ...
# 2020-04-17      2113573      84339        144820        8507
# 2020-04-18      2196897      83324        153083        8263
# 2020-04-19      2281018      84121        159504        6421
# 2020-04-20      2355157      74139        164649        5145
# 2020-04-21      2431194      76037        169852        5203
#
#             total_cases_per_million  new_cases_per_million  \
# date
# 2019-12-31                    0.019                  0.019
# 2020-01-01                    0.019                  0.000
# 2020-01-02                    0.019                  0.000
# 2020-01-03                    0.031                  0.012
# 2020-01-04                    0.031                  0.000
# ...                             ...                    ...
# 2020-04-17               130431.327               4264.388
# 2020-04-18               133477.548               3046.219
# 2020-04-19               136797.443               3319.896
# 2020-04-20               139621.453               2824.004
# 2020-04-21               143254.996               3633.542
#
#             total_deaths_per_million  new_deaths_per_million  total_tests  \
# date
# 2019-12-31                     0.000                   0.000          0.0
# 2020-01-01                     0.000                   0.000          0.0
# 2020-01-02                     0.000                   0.000          0.0
# 2020-01-03                     0.000                   0.000          0.0
# 2020-01-04                     0.000                   0.000          0.0
# ...                              ...                     ...          ...
# 2020-04-17                  5640.059                 254.871   13409298.0
# 2020-04-18                  5871.547                 231.486   14259188.0
# 2020-04-19                  6059.976                 188.430   15132800.0
# 2020-04-20                  6247.393                 187.415   14581366.0
# 2020-04-21                  6410.625                 163.235    9500100.0
#
#             new_tests  total_tests_per_thousand  new_tests_per_thousand
# date
# 2019-12-31        0.0                     0.000                   0.000
# 2020-01-01        0.0                     0.000                   0.000
# 2020-01-02        0.0                     0.000                   0.000
# 2020-01-03        0.0                     0.000                   0.000
# 2020-01-04        0.0                     0.000                   0.000
# ...               ...                       ...                     ...
# 2020-04-17   651589.0                   668.010                  27.842
# 2020-04-18   655279.0                   701.770                  27.698
# 2020-04-19   679329.0                   731.694                  23.597
# 2020-04-20   552767.0                   717.527                  20.125
# 2020-04-21   292353.0                   434.032                  13.630
#
# [113 rows x 12 columns]

# %%
#Global cases vs tests

#data
groupby_global = df.groupby('date').sum()
x = groupby_global.new_tests
y = groupby_global.new_cases

plt.scatter(x,y)
plt.title("COVID-19 Cases vs number of Tests")
plt.xlabel("Tests")
plt.ylabel("Cases")

plt.savefig('/Users/sebastiangraff/Desktop/Data_Analysis/COVID19-Exploration/plot_images/global_tests_vs_cases.png')
plt.show();

# %%
#Global cases vs tests

#data
groupby_global = df.groupby('date').sum()
x = groupby_global.new_tests
y = groupby_global.new_cases

plt.scatter(x,y)
plt.title("COVID-19 Cases vs number of Tests")
plt.xlabel("Tests")
plt.ylabel("Cases")

plt.savefig('/Users/sebastiangraff/Desktop/Data_Analysis/COVID19-Exploration/plot_images/cases_by_country.png')
plt.show();
